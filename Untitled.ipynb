# %%
import re

# %%
data="""
html.Div([
            html.Div([
                <ul class="menu accordion">

                    html.Li([
                        
                    ])
                    html.Li([
                        
                    ])
                    
                    html.Li([
                       
                    ])
                    html.Li([
                        
                        html.Ol([
                            html.Li([
                               
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                               
                            ])
                        ])

                    ])

                    html.Li([
                        
                        <ul class="menu collapse" data-parent="#main-menu" id="menu-1fc88e">


                            html.Li([
                               
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                               
                            ])


                            html.Li([
                                
                            ])


                            html.Li([
                               
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                              
                            ])

                        </ul>
                    ])



                    html.Li([
                       
                    ])

                    html.Li([
                       
                    ])

                    html.Li([
                      
                        <ul class="menu collapse" data-parent="#main-menu" id="menu-96b24e">

                            html.Li([
                                
                            ])

                            html.Li([
                                
                            ])


                        </ul>
                    ])

                    html.Li([
                        
                        <ul class="menu collapse" data-parent="#main-menu" id="menu-62d0a7">

                            html.Li([
                               
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                               
                            ])

                            html.Li([
                              
                            ])

                            html.Li([
                               
                            ])


                            html.Li([
                               
                            ])


                        </ul>
                    ])

                    html.Li([
                       
                    ])

                    html.Li([
                      

                        <ul class="menu collapse" data-parent="#main-menu" id="menu-40ebea">
                            html.Li([
                             
                            ])

                            html.Li([
                                
                            ])

                            html.Li([
                              
                            ])
                        </ul>
                    ])

                    html.Li([
                                          ])


                    html.Li([
                       
                    ])


                </ul>
            ])

            
        ])
"""

# %%
d=re.compile('<ul(?=\s).*',re.M)

# %%
real=d.subn('html.Ol([',data)

# %%
print(re.findall(re.compile('<a(?=\s\w).*(?<=)</a>',re.M),data))
# Out:
# []

# %%
ss=re.compile('</ul>')
print(ss.subn('])',real[0])[0])
# Out:
# html.Div([
#             html.Div([
#                 html.Ol([
#
#                     html.Li([
#
#                     ])
#                     html.Li([
#
#                     ])
#
#                     html.Li([
#
#                     ])
#                     html.Li([
#
#                         html.Ol([
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#                         ])
#
#                     ])
#
#                     html.Li([
#
#                         html.Ol([
#
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#
#                             html.Li([
#
#                             ])
#
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                         ])
#                     ])
#
#
#
#                     html.Li([
#
#                     ])
#
#                     html.Li([
#
#                     ])
#
#                     html.Li([
#
#                         html.Ol([
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#
#                         ])
#                     ])
#
#                     html.Li([
#
#                         html.Ol([
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#
#                             html.Li([
#
#                             ])
#
#
#                         ])
#                     ])
#
#                     html.Li([
#
#                     ])
#
#                     html.Li([
#
#
#                         html.Ol([
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#
#                             html.Li([
#
#                             ])
#                         ])
#                     ])
#
#                     html.Li([
#                                           ])
#
#
#                     html.Li([
#
#                     ])
#
#
#                 ])
#             ])
#
#
#         ])
